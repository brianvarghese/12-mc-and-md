# %%
# equal mass homogeneous initial conditions 4 seconds #

import numpy as np
import matplotlib.pyplot as plt
import itertools as it
from matplotlib.animation import FuncAnimation
from numba import jit
from time import time
from numpy.random import random
from scipy.fft import fft2, fft, fftfreq
import os

class Molecular_Dynamics:
    def __init__(self, N, L, dt, t_max, x, v, m, delta=1):
        self.L = L
        self.t_max = t_max
        self.dt = dt
        self.m = m
        self.delta = delta
        self.x = x
        self.v = v
        self.x_data = [x]
        self.v_data = [v]
        self.t = [0]
        self.pair_idx = tuple((i, i+1) for i in range(N-1))   # pair index 
        self.single_idx = (0, N-1)
        self.number_of_events = 0
        
        
    def simulation(self): 
        while self.t[-1] < t_max:
            t_event, event_idx = self.compute_next_event()
            for i in range(int(self.t[-1]/self.dt)+1, int((self.t[-1]+t_event)/dt)+1):
                self.x = np.copy(self.x + self.v * self.dt)
                self.x_data.append(self.x)
                self.v_data.append(self.v)
                self.t.append(self.t[-1] + self.dt)
                if self.t[-1] >= self.t_max: break
            self.update_v(event_idx)
            self.number_of_events += 1
            
    def get_data(self, p):
        x_data = np.array(self.x_data)[:-1]  
        v_data = np.array(self.v_data)[:-1]  
        E_data = 0.5 * self.m * v_data**2
        t = np.array(self.t)[:-1]
        if p: print("number of collisions", self.number_of_events)
        return x_data, v_data, E_data, t
        
    def pair_time(self, xi, xj, vi, vj):
        dv = vi - vj
        if dv < 0: return np.inf
        return (xj - xi - self.delta)/dv
    
    def pair_collision(self, vi, vj, mi, mj):
        vi_f = vi*(mi-mj)/(mi+mj) + vj*2*mj/(mi+mj)
        vj_f = vi*2*mi/(mi+mj) - vj*(mi-mj)/(mi+mj)
        return vi_f, vj_f
    
    def wall_time(self, x0, xN, v0, vN):
        t0 = (x0 - self.delta/2)/abs(v0) if v0 < 0 else np.inf
        tn = (L - xN - self.delta/2)/vN if vN > 0 else np.inf
        return [t0, tn]
    
    def wall_collision(self, vi):
        return -vi
    
    def compute_next_event(self):
        x, v = self.x, self.v
        pair_times = [self.pair_time(x[i], x[j], v[i], v[j]) for i, j in self.pair_idx]
        wall_times = self.wall_time(x[0], x[-1], v[0], v[-1])
        times = np.array(wall_times + pair_times)
        arg = np.argmin(times)
        t_event = times[arg]
        event_idx = self.single_idx[arg] if arg < 2 else self.pair_idx[arg-2]
        return t_event, event_idx
    
    def update_v(self, event_idx):
        v = self.v.copy()
        if type(event_idx) == tuple:
            i, j = event_idx # i and the i+1 element pair(i,j)
            v[i], v[j] = self.pair_collision(v[i], v[j], m[i], m[j])
        else:
            i = event_idx
            v[i] = self.wall_collision(v[i])
        self.v = v
        
class Monte_Carlo:
    def __init__(self, L, delta = 1, T=1):
        self.L = L # length of simulation box
        self.delta = delta # size of the particles
        self.T = T # temperature 
        
    def sample_configuration(self):
        x = self.sample_positions()
        N = len(x)
        m = np.ones(N)
        v = self.sample_velocities(N, m)
        print('number of particles', N)
        return x, v, m
   
    def sample_velocities(self, N, m):
        k_b = 1.38064
        sigma = np.sqrt((k_b * self.T)/m)
        v = np.random.normal(loc = 0, scale = sigma, size=N)
        return v
    
    def sample_positions(self):
        x_positions = []
        next_position = 0.5 + np.random.poisson(2)
        while next_position < self.L - 0.5:
            x_positions.append(next_position)
            next_position = x_positions[-1] + 1 + np.random.poisson(1)
        return x_positions
    
def observables(nbins, x_data, v_data, E_data, m, N):
    x_grid = np.linspace(0, L, nbins)
    dx = x_grid[1]
    
    enumerate(x_grid)
    
    q0 = np.zeros((len(t),len(x_grid)))
    q1 = np.zeros((len(t),len(x_grid)))
    q2 = np.zeros((len(t),len(x_grid)))
    
    j0 = np.zeros((len(t),len(x_grid)))
    j1 = np.zeros((len(t),len(x_grid)))
    j2 = np.zeros((len(t),len(x_grid)))
    
    for ((x_, v_), (E_, m_)) in zip(zip(x_data.T, v_data.T), zip(E_data.T, m)):
        for i, a in enumerate(x_grid):
            idx = np.logical_and(a < x_, x_ < a + dx)
            q0[:,i] += idx.astype(int)
            q1[:,i] += v_*m_*idx.astype(int)
            q2[:,i] += E_*idx.astype(int)
            j0[:,i] += v_*idx.astype(int)
            j1[:,i] += v_*m_*v_*idx.astype(int)
            j2[:,i] += E_*v_*idx.astype(int)
    
            
    q0 = q0 / N
    q1 = q1 / N
    q2 = q2 / N
    
    j0 = j0 / N
    j1 = j1 / N
    j2 = j2 / N
    
    return x_grid, q0, q1, q2, j0, j1, j2

L = 500
t_max = 4
dt = 0.001

MC = Monte_Carlo(L, T = 293.15)

n_MC = 1000

for i in range(n_MC):
    x, v, m = MC.sample_configuration()

    N = len(x)

    MD = Molecular_Dynamics(N, L, dt, t_max, x, v, m)
    MD.simulation()

    x_data, v_data, E_data, t = MD.get_data(p = True)

    nbins = 50

    x_grid, q0, q1, q2, j0, j1, j2 = observables(nbins, x_data, v_data, E_data, m, N)

    mid = q0.shape[1]//2 #Half of the box (position we want to correlate)#
    
    maxtime = 4000
 
    if i == 0:
        term11 = q0[0:maxtime, :] * q0[0,mid]
        term21 = q0[0:maxtime,:]
        term31 = q0[0,mid]
        
        term12 = q1[0:maxtime, :] * q1[0,mid]
        term22 = q1[0:maxtime,:]
        term32 = q1[0,mid]
        
        
        term13 = q2[0:maxtime, :] * q2[0,mid]
        term23 = q2[0:maxtime,:]
        term33 = q2[0,mid]
        
        
        term14 = j0[0:maxtime, :] * j0[0,mid]
        term24 = j0[0:maxtime,:]
        term34 = j0[0,mid]
        
        
        term15 = j1[0:maxtime, :] * j1[0,mid]
        term25 = j1[0:maxtime,:]
        term35 = j1[0,mid]
        
        
        term16 = j2[0:maxtime, :] * j2[0,mid]
        term26 = j2[0:maxtime,:]
        term36 = j2[0,mid]
        
        print(i)

    else:
        term11 += q0[0:maxtime, :] * q0[0,mid]
        term21 += q0[0:maxtime,:]
        term31 += q0[0,mid]
        
        term12 += q1[0:maxtime, :] * q1[0,mid]
        term22 += q1[0:maxtime,:]
        term32 += q1[0,mid]
        
        term13 += q2[0:maxtime, :] * q2[0,mid]
        term23 += q2[0:maxtime,:]
        term33 += q2[0,mid]
        
        term14 += j0[0:maxtime, :] * j0[0,mid]
        term24 += j0[0:maxtime,:]
        term34 += j0[0,mid]
       
        term15 += j1[0:maxtime, :] * j1[0,mid]
        term25 += j1[0:maxtime,:]
        term35 += j1[0,mid]
       
        term16 += j2[0:maxtime, :] * j2[0,mid]
        term26 += j2[0:maxtime,:]
        term36 += j2[0,mid]
        
       
        print(i)

C0 = (term11 / n_MC) - ((term31 / n_MC)*(term21 / n_MC))
C1 = (term12 / n_MC) - ((term32 / n_MC)*(term22 / n_MC))
C2 = (term13 / n_MC) - ((term33 / n_MC)*(term23 / n_MC))
C3 = (term14 / n_MC) - ((term34 / n_MC)*(term24 / n_MC))
C4 = (term15 / n_MC) - ((term35 / n_MC)*(term25 / n_MC))
C5 = (term16 / n_MC) - ((term36 / n_MC)*(term26 / n_MC))

maxtime = 4000

T, X = np.meshgrid(t[:maxtime], x_grid)

pcm1 = plt.pcolormesh(X, T, C0.T)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm2 = plt.pcolormesh(X, T, C1.T)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm3 = plt.pcolormesh(X, T, C2.T)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm4 = plt.pcolormesh(X, T, C3.T)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm5 = plt.pcolormesh(X, T, C4.T)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

pcm6 = plt.pcolormesh(X, T, C5.T)
plt.title('Energy-Eenrgy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

T, X = np.meshgrid(t[:maxtime], x_grid)

C0FT1 = np.fft.fft(C0, axis = 1)
C0IFT1 = np.fft.ifft(C0FT1, axis = 0)
pcm7 = plt.pcolormesh(X, T,np.abs(C0IFT1).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C0FT2 = np.fft.fft(C0, axis = 0)
C0IFT2 = np.fft.ifft(C0FT2, axis = 1)
pcm8 = plt.pcolormesh(X, T,np.abs(C0IFT2).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C1FT1 = np.fft.fft(C1, axis = 1)
C1IFT1 = np.fft.ifft(C1FT1, axis = 0)
pcm9 = plt.pcolormesh(X, T,np.abs(C1IFT1).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C1FT2 = np.fft.fft(C1, axis = 0)
C1IFT2 = np.fft.ifft(C1FT2, axis = 1)
pcm10 = plt.pcolormesh(X, T,np.abs(C1IFT2).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C2FT1 = np.fft.fft(C2, axis = 1)
C2IFT1 = np.fft.ifft(C2FT1, axis = 0)
pcm11 = plt.pcolormesh(X, T,np.abs(C2IFT1).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C2FT2 = np.fft.fft(C2, axis = 0)
C2IFT2 = np.fft.ifft(C2FT2, axis = 1)
pcm12 = plt.pcolormesh(X, T,np.abs(C2IFT2).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C3FT1 = np.fft.fft(C3, axis = 1)
C3IFT1 = np.fft.ifft(C3FT1, axis = 0)
pcm13 = plt.pcolormesh(X, T,np.abs(C3IFT1).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C3FT2 = np.fft.fft(C3, axis = 0)
C3IFT2 = np.fft.ifft(C3FT2, axis = 1)
pcm14 = plt.pcolormesh(X, T,np.abs(C3IFT2).T, vmin = 0, vmax = 20)
plt.title('Density-Density')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C4FT1 = np.fft.fft(C4, axis = 1)
C4IFT1 = np.fft.ifft(C4FT1, axis = 0)
pcm15 = plt.pcolormesh(X, T,np.abs(C4IFT1).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C4FT2 = np.fft.fft(C4, axis = 0)
C4IFT2 = np.fft.ifft(C4FT2, axis = 1)
pcm16 = plt.pcolormesh(X, T,np.abs(C4IFT2).T, vmin = 0, vmax = 20)
plt.title('Momentum-Momentum')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C5FT1 = np.fft.fft(C5, axis = 1)
C5IFT1 = np.fft.ifft(C5FT1, axis = 0)
pcm17 = plt.pcolormesh(X, T,np.abs(C5IFT1).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()

C5FT2 = np.fft.fft(C5, axis = 0)
C5IFT2 = np.fft.ifft(C5FT2, axis = 1)
pcm18 = plt.pcolormesh(X, T,np.abs(C5IFT2).T, vmin = 0, vmax = 20)
plt.title('Energy-Energy')
plt.xlabel('x')
plt.ylabel('t')
plt.colorbar()
plt.show()
# Out:
# number of particles 239
# number of collisions 9589
# 0
# number of particles 245
# number of collisions 11139
# 1
# number of particles 244
# number of collisions 9789
# 2
# number of particles 259
# number of collisions 12212
# 3
# number of particles 253
# number of collisions 11660
# 4
# number of particles 233
# number of collisions 8874
# 5
# number of particles 239
# number of collisions 9762
# 6
# number of particles 256
# number of collisions 11245
# 7
# number of particles 262
# number of collisions 12350
# 8
# number of particles 235
# number of collisions 9667
# 9
# number of particles 235
# number of collisions 9955
# 10
# number of particles 249
# number of collisions 10903
# 11
# number of particles 237
# number of collisions 10066
# 12
# number of particles 262
# number of collisions 12813
# 13
# number of particles 229
# number of collisions 7484
# 14
# number of particles 246
# number of collisions 10766
# 15
# number of particles 237
# number of collisions 9481
# 16
# number of particles 254
# number of collisions 11588
# 17
# number of particles 262
# number of collisions 13231
# 18
# number of particles 238
# number of collisions 9166
# 19
# number of particles 257
# number of collisions 12763
# 20
# number of particles 249
# number of collisions 10693
# 21
# number of particles 244
# number of collisions 9894
# 22
# number of particles 246
# number of collisions 10001
# 23
# number of particles 241
# number of collisions 9993
# 24
# number of particles 248
# number of collisions 10922
# 25
# number of particles 229
# number of collisions 8541
# 26
# number of particles 248
# number of collisions 10723
# 27
# number of particles 252
# number of collisions 11902
# 28
# number of particles 246
# number of collisions 10600
# 29
# number of particles 260
# number of collisions 12853
# 30
# number of particles 238
# number of collisions 9401
# 31
# number of particles 245
# number of collisions 10600
# 32
# number of particles 247
# number of collisions 10158
# 33
# number of particles 243
# number of collisions 10834
# 34
# number of particles 243
# number of collisions 10163
# 35
# number of particles 238
# number of collisions 9706
# 36
# number of particles 240
# number of collisions 9544
# 37
# number of particles 249
# number of collisions 11326
# 38
# number of particles 261
# number of collisions 12737
# 39
# number of particles 252
# number of collisions 11532
# 40
# number of particles 250
# number of collisions 9850
# 41
# number of particles 246
# number of collisions 10973
# 42
# number of particles 247
# number of collisions 11288
# 43
# number of particles 248
# number of collisions 10986
# 44
# number of particles 253
# number of collisions 11819
# 45
# number of particles 255
# number of collisions 11254
# 46
# number of particles 250
# number of collisions 10199
# 47
# number of particles 242
# number of collisions 9956
# 48
# number of particles 239
# number of collisions 9893
# 49
# number of particles 243
# number of collisions 10052
# 50
# number of particles 250
# number of collisions 11463
# 51
# number of particles 247
# number of collisions 10120
# 52
# number of particles 248
# number of collisions 11325
# 53
# number of particles 240
# number of collisions 9953
# 54
# number of particles 252
# number of collisions 10696
# 55
# number of particles 241
# number of collisions 10764
# 56
# number of particles 268
# number of collisions 13539
# 57
# number of particles 252
# number of collisions 10834
# 58
# number of particles 235
# number of collisions 9142
# 59
# number of particles 258
# number of collisions 13072
# 60
# number of particles 255
# number of collisions 11540
# 61
# number of particles 264
# number of collisions 13532
# 62
# number of particles 252
# number of collisions 11949
# 63
# number of particles 257
# number of collisions 12062
# 64
# number of particles 247
# number of collisions 11479
# 65
# number of particles 259
# number of collisions 12228
# 66
# number of particles 256
# number of collisions 12076
# 67
# number of particles 245
# number of collisions 10096
# 68
# number of particles 252
# number of collisions 12180
# 69
# number of particles 232
# number of collisions 8715
# 70
# number of particles 239
# number of collisions 9769
# 71
# number of particles 250
# number of collisions 11207
# 72
# number of particles 247
# number of collisions 10854
# 73
# number of particles 252
# number of collisions 10980
# 74
# number of particles 255
# number of collisions 12228
# 75
# number of particles 257
# number of collisions 12496
# 76
# number of particles 240
# number of collisions 10565
# 77
# number of particles 240
# number of collisions 10920
# 78
# number of particles 252
# number of collisions 11586
# 79
# number of particles 252
# number of collisions 11802
# 80
# number of particles 236
# number of collisions 9642
# 81
# number of particles 235
# number of collisions 8688
# 82
# number of particles 239
# number of collisions 10306
# 83
# number of particles 240
# number of collisions 10378
# 84
# number of particles 235
# number of collisions 9808
# 85
# number of particles 249
# number of collisions 11584
# 86
# number of particles 250
# number of collisions 12129
# 87
# number of particles 247
# number of collisions 11615
# 88
# number of particles 255
# number of collisions 12181
# 89
# number of particles 245
# number of collisions 9910
# 90
# number of particles 250
# number of collisions 11146
# 91
# number of particles 248
# number of collisions 10613
# 92
# number of particles 237
# number of collisions 8763
# 93
# number of particles 261
# number of collisions 12704
# 94
# number of particles 248
# number of collisions 10944
# 95
# number of particles 241
# number of collisions 10838
# 96
# number of particles 252
# number of collisions 11741
# 97
# number of particles 246
# number of collisions 10989
# 98
# number of particles 252
# number of collisions 11559
# 99
# number of particles 250
# number of collisions 11059
# 100
# number of particles 252
# number of collisions 12081
# 101
# number of particles 250
# number of collisions 11154
# 102
# number of particles 243
# number of collisions 10238
# 103
# number of particles 244
# number of collisions 10778
# 104
# number of particles 254
# number of collisions 10665
# 105
# number of particles 257
# number of collisions 12843
# 106
# number of particles 262
# number of collisions 13250
# 107
# number of particles 244
# number of collisions 10533
# 108
# number of particles 235
# number of collisions 8637
# 109
# number of particles 248
# number of collisions 12373
# 110
# number of particles 247
# number of collisions 11463
# 111
# number of particles 237
# number of collisions 8723
# 112
# number of particles 242
# number of collisions 10825
# 113
# number of particles 265
# number of collisions 13652
# 114
# number of particles 237
# number of collisions 9618
# 115
# number of particles 254
# number of collisions 12485
# 116
# number of particles 231
# number of collisions 9018
# 117
# number of particles 238
# number of collisions 9964
# 118
# number of particles 259
# number of collisions 12625
# 119
# number of particles 231
# number of collisions 9283
# 120
# number of particles 250
# number of collisions 9971
# 121
# number of particles 255
# number of collisions 10968
# 122
# number of particles 260
# number of collisions 12959
# 123
# number of particles 237
# number of collisions 8948
# 124
# number of particles 243
# number of collisions 10560
# 125
# number of particles 267
# number of collisions 13503
# 126
# number of particles 243
# number of collisions 9501
# 127
# number of particles 260
# number of collisions 13407
# 128
# number of particles 243
# number of collisions 10975
# 129
# number of particles 257
# number of collisions 12077
# 130
# number of particles 246
# number of collisions 10098
# 131
# number of particles 244
# number of collisions 10065
# 132
# number of particles 267
# number of collisions 12536
# 133
# number of particles 252
# number of collisions 11488
# 134
# number of particles 271
# number of collisions 14572
# 135
# number of particles 238
# number of collisions 9540
# 136
# number of particles 260
# number of collisions 13282
# 137
# number of particles 242
# number of collisions 10160
# 138
# number of particles 256
# number of collisions 12142
# 139
# number of particles 235
# number of collisions 9731
# 140
# number of particles 257
# number of collisions 12631
# 141
# number of particles 265
# number of collisions 13569
# 142
# number of particles 246
# number of collisions 10287
# 143
# number of particles 253
# number of collisions 11651
# 144
# number of particles 245
# number of collisions 10874
# 145
# number of particles 246
# number of collisions 10772
# 146
# number of particles 254
# number of collisions 12131
# 147
# number of particles 257
# number of collisions 12990
# 148
# number of particles 247
# number of collisions 10577
# 149
# number of particles 253
# number of collisions 12303
# 150
# number of particles 260
# number of collisions 14152
# 151
# number of particles 247
# number of collisions 11447
# 152
# number of particles 239
# number of collisions 9811
# 153
# number of particles 242
# number of collisions 10201
# 154
# number of particles 244
# number of collisions 10571
# 155
# number of particles 248
# number of collisions 11157
# 156
# number of particles 241
# number of collisions 9909
# 157
# number of particles 261
# number of collisions 12061
# 158
# number of particles 248
# number of collisions 11720
# 159
# number of particles 260
# number of collisions 12232
# 160
# number of particles 254
# number of collisions 11276
# 161
# number of particles 242
# number of collisions 10670
# 162
# number of particles 239
# number of collisions 9023
# 163
# number of particles 258
# number of collisions 12012
# 164
# number of particles 242
# number of collisions 10751
# 165
# number of particles 235
# number of collisions 9465
# 166
# number of particles 242
# number of collisions 9668
# 167
# number of particles 260
# number of collisions 11925
# 168
# number of particles 244
# number of collisions 9697
# 169
# number of particles 246
# number of collisions 10907
# 170
# number of particles 243
# number of collisions 10790
# 171
# number of particles 239
# number of collisions 10141
# 172
# number of particles 253
# number of collisions 11073
# 173
# number of particles 245
# number of collisions 10418
# 174
# number of particles 261
# number of collisions 13138
# 175
# number of particles 255
# number of collisions 12335
# 176
# number of particles 242
# number of collisions 9244
# 177
# number of particles 237
# number of collisions 9531
# 178
# number of particles 249
# number of collisions 10708
# 179
# number of particles 246
# number of collisions 10307
# 180
# number of particles 256
# number of collisions 11843
# 181
# number of particles 255
# number of collisions 12099
# 182
# number of particles 236
# number of collisions 9841
# 183
# number of particles 252
# number of collisions 11761
# 184
# number of particles 241
# number of collisions 10485
# 185
# number of particles 252
# number of collisions 11077
# 186
# number of particles 235
# number of collisions 9835
# 187
# number of particles 242
# number of collisions 9686
# 188
# number of particles 249
# number of collisions 11500
# 189
# number of particles 253
# number of collisions 11339
# 190
# number of particles 271
# number of collisions 14253
# 191
# number of particles 261
# number of collisions 11837
# 192
# number of particles 244
# number of collisions 10322
# 193
# number of particles 245
# number of collisions 10206
# 194
# number of particles 237
# number of collisions 9893
# 195
# number of particles 236
# number of collisions 9583
# 196
# number of particles 237
# number of collisions 9736
# 197
# number of particles 259
# number of collisions 12764
# 198
# number of particles 252
# number of collisions 11891
# 199
# number of particles 262
# number of collisions 13227
# 200
# number of particles 229
# number of collisions 8719
# 201
# number of particles 248
# number of collisions 11152
# 202
# number of particles 260
# number of collisions 12805
# 203
# number of particles 251
# number of collisions 12149
# 204
# number of particles 250
# number of collisions 11803
# 205
# number of particles 241
# number of collisions 10349
# 206
# number of particles 243
# number of collisions 10264
# 207
# number of particles 234
# number of collisions 9883
# 208
# number of particles 239
# number of collisions 9169
# 209
# number of particles 256
# number of collisions 11959
# 210
# number of particles 253
# number of collisions 11138
# 211
# number of particles 253
# number of collisions 12074
# 212
# number of particles 261
# number of collisions 12845
# 213
# number of particles 239
# number of collisions 10468
# 214
# number of particles 242
# number of collisions 9852
# 215
# number of particles 253
# number of collisions 12141
# 216
# number of particles 236
# number of collisions 9680
# 217
# number of particles 256
# number of collisions 12081
# 218
# number of particles 252
# number of collisions 11236
# 219
# number of particles 266
# number of collisions 13796
# 220
# number of particles 245
# number of collisions 10149
# 221
# number of particles 253
# number of collisions 11481
# 222
# number of particles 250
# number of collisions 10686
# 223
# number of particles 249
# number of collisions 11736
# 224
# number of particles 248
# number of collisions 10956
# 225
# number of particles 258
# number of collisions 12038
# 226
# number of particles 244
# number of collisions 10263
# 227
# number of particles 256
# number of collisions 12581
# 228
# number of particles 245
# number of collisions 10587
# 229
# number of particles 265
# number of collisions 14356
# 230
# number of particles 243
# number of collisions 10643
# 231
# number of particles 256
# number of collisions 12427
# 232
# number of particles 254
# number of collisions 12579
# 233
# number of particles 256
# number of collisions 11558
# 234
# number of particles 256
# number of collisions 12124
# 235
# number of particles 247
# number of collisions 10577
# 236
# number of particles 255
# number of collisions 12081
# 237
# number of particles 250
# number of collisions 9896
# 238
# number of particles 249
# number of collisions 11164
# 239
# number of particles 251
# number of collisions 10988
# 240
# number of particles 238
# number of collisions 9582
# 241
# number of particles 255
# number of collisions 13179
# 242
# number of particles 235
# number of collisions 9797
# 243
# number of particles 257
# number of collisions 12329
# 244
# number of particles 247
# number of collisions 11347
# 245
# number of particles 244
# number of collisions 10815
# 246
# number of particles 246
# number of collisions 10907
# 247
# number of particles 241
# number of collisions 10674
# 248
# number of particles 250
# number of collisions 11535
# 249
# number of particles 252
# number of collisions 11644
# 250
# number of particles 245
# number of collisions 10959
# 251
# number of particles 255
# number of collisions 11974
# 252
# number of particles 249
# number of collisions 10210
# 253
# number of particles 253
# number of collisions 10988
# 254
# number of particles 249
# number of collisions 10761
# 255
# number of particles 243
# number of collisions 10519
# 256
# number of particles 267
# number of collisions 13833
# 257
# number of particles 257
# number of collisions 12384
# 258
# number of particles 251
# number of collisions 11596
# 259
# number of particles 243
# number of collisions 10722
# 260
# number of particles 252
# number of collisions 11477
# 261
# number of particles 251
# number of collisions 11352
# 262
# number of particles 259
# number of collisions 12171
# 263
# number of particles 246
# number of collisions 10867
# 264
# number of particles 255
# number of collisions 11321
# 265
# number of particles 233
# number of collisions 9364
# 266
# number of particles 247
# number of collisions 11095
# 267
# number of particles 246
# number of collisions 10549
# 268
# number of particles 268
# number of collisions 13009
# 269
# number of particles 254
# number of collisions 11081
# 270
# number of particles 248
# number of collisions 11460
# 271
# number of particles 238
# number of collisions 9163
# 272
# number of particles 239
# number of collisions 10070
# 273
# number of particles 253
# number of collisions 12662
# 274
# number of particles 239
# number of collisions 10381
# 275
# number of particles 255
# number of collisions 12328
# 276
# number of particles 238
# number of collisions 9795
# 277
# number of particles 243
# number of collisions 11091
# 278
# number of particles 252
# number of collisions 11635
# 279
# number of particles 260
# number of collisions 12469
# 280
# number of particles 248
# number of collisions 11362
# 281
# number of particles 242
# number of collisions 9707
# 282
# number of particles 254
# number of collisions 11954
# 283
# number of particles 262
# number of collisions 13100
# 284
# number of particles 245
# number of collisions 9900
# 285
# number of particles 245
# number of collisions 9936
# 286
# number of particles 246
# number of collisions 10535
# 287
# number of particles 235
# number of collisions 9103
# 288
# number of particles 245
# number of collisions 9648
# 289
# number of particles 266
# number of collisions 13380
# 290
# number of particles 250
# number of collisions 11850
# 291
# number of particles 251
# number of collisions 12303
# 292
# number of particles 244
# number of collisions 10055
# 293
# number of particles 240
# number of collisions 9829
# 294
# number of particles 243
# number of collisions 10270
# 295
# number of particles 249
# number of collisions 10204
# 296
# number of particles 251
# number of collisions 10722
# 297
# number of particles 243
# number of collisions 10103
# 298
# number of particles 239
# number of collisions 8547
# 299
# number of particles 250
# number of collisions 11486
# 300
# number of particles 251
# number of collisions 11388
# 301
# number of particles 251
# number of collisions 11814
# 302
# number of particles 258
# number of collisions 11644
# 303
# number of particles 265
# number of collisions 12516
# 304
# number of particles 258
# number of collisions 11487
# 305
# number of particles 242
# number of collisions 10198
# 306
# number of particles 239
# number of collisions 10385
# 307
# number of particles 258
# number of collisions 12387
# 308
# number of particles 262
# number of collisions 12415
# 309
# number of particles 257
# number of collisions 12868
# 310
# number of particles 244
# number of collisions 9959
# 311
# number of particles 254
# number of collisions 11782
# 312
# number of particles 249
# number of collisions 10825
# 313
# number of particles 252
# number of collisions 11669
# 314
# number of particles 252
# number of collisions 11847
# 315
# number of particles 244
# number of collisions 9490
# 316
# number of particles 245
# number of collisions 11237
# 317
# number of particles 257
# number of collisions 12121
# 318
# number of particles 237
# number of collisions 9502
# 319
# number of particles 231
# number of collisions 8784
# 320
# number of particles 253
# number of collisions 12146
# 321
# number of particles 247
# number of collisions 11222
# 322
# number of particles 252
# number of collisions 11180
# 323
# number of particles 243
# number of collisions 10246
# 324
# number of particles 236
# number of collisions 9016
# 325
# number of particles 246
# number of collisions 11024
# 326
# number of particles 255
# number of collisions 10862
# 327
# number of particles 253
# number of collisions 11863
# 328
# number of particles 246
# number of collisions 9713
# 329
# number of particles 233
# number of collisions 9423
# 330
# number of particles 242
# number of collisions 10568
# 331
# number of particles 248
# number of collisions 10715
# 332
# number of particles 242
# number of collisions 9967
# 333
# number of particles 263
# number of collisions 13756
# 334
# number of particles 252
# number of collisions 11668
# 335
# number of particles 247
# number of collisions 11189
# 336
# number of particles 246
# number of collisions 11078
# 337
# number of particles 240
# number of collisions 9760
# 338
# number of particles 238
# number of collisions 9332
# 339
# number of particles 259
# number of collisions 12034
# 340
# number of particles 251
# number of collisions 11113
# 341
# number of particles 254
# number of collisions 11463
# 342
# number of particles 237
# number of collisions 9504
# 343
# number of particles 252
# number of collisions 12065
# 344
# number of particles 247
# number of collisions 10358
# 345
# number of particles 249
# number of collisions 10923
# 346
# number of particles 251
# number of collisions 10873
# 347
# number of particles 244
# number of collisions 10966
# 348
# number of particles 237
# number of collisions 8906
# 349
# number of particles 247
# number of collisions 11650
# 350
# number of particles 259
# number of collisions 12807
# 351
# number of particles 240
# number of collisions 9745
# 352
# number of particles 246
# number of collisions 10788
# 353
# number of particles 253
# number of collisions 12190
# 354
# number of particles 256
# number of collisions 12127
# 355
# number of particles 253
# number of collisions 11742
# 356
# number of particles 241
# number of collisions 10230
# 357
# number of particles 259
# number of collisions 13146
# 358
# number of particles 261
# number of collisions 13587
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-97e2836f4d40> in <module>
#     169     nbins = 50
#     170
# --> 171     x_grid, q0, q1, q2, j0, j1, j2 = observables(nbins, x_data, v_data, E_data, m, N)
#     172
#     173     mid = q0.shape[1]//2 #Half of the box (position we want to correlate)#
#
# <ipython-input-3-97e2836f4d40> in observables(nbins, x_data, v_data, E_data, m, N)
#     134             q1[:,i] += v_*m_*idx.astype(int)
#     135             q2[:,i] += E_*idx.astype(int)
# --> 136             j0[:,i] += v_*idx.astype(int)
#     137             j1[:,i] += v_*m_*v_*idx.astype(int)
#     138             j2[:,i] += E_*v_*idx.astype(int)
#
# KeyboardInterrupt:
